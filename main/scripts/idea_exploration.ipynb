# %%
import pandas as pd

from utils import *

# %%
file_name_load = "2023-09-08_12-26"
image_path = f"../images/images_raw/{file_name_load}.jpg"

raw_image = cv2.imread(image_path)
raw_image = cv2.resize(raw_image, (720, 1080))

plot_results(raw_image, scale=0.5)
# Out:
# <PIL.Image.Image image mode=RGB size=360x540>

# %%
hsv_image = cv2.cvtColor(raw_image, cv2.COLOR_BGR2HSV)
